# %%
# !git clone https://github.com/coreeey/OCT2Former.git
# Out:
# Cloning into 'OCT2Former'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 174 (delta 46), reused 96 (delta 45), pack-reused 77
# Receiving objects: 100% (174/174), 124.56 KiB | 15.57 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# !pip install albumentations==0.4.6 einops thop ml_collections
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.1 MB/s eta 0:00:00
# ...
#   Created wheel for albumentations: filename=albumentations-0.4.6-py3-none-any.whl size=65152 sha256=6641ca28f040e00b118e144e5180382fcf067dc813320d41e823fa13ba74d17d
#   Stored in directory: /root/.cache/pip/wheels/f9/d7/0c/6ed42fd872f7d1af78b25045f8b16be330f2c70ae72c83e37d
# ...
#   Created wheel for ml_collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94507 sha256=3ddf1f195e7aefd559f6f96dc0042057b647162a7c753b5371da1168c1bc2bdc
#   Stored in directory: /root/.cache/pip/wheels/7b/89/c9/a9b87790789e94aadcfc393c283e3ecd5ab916aed0a31be8fe
# Successfully built albumentations ml_collections
# ...
#   Attempting uninstall: albumentations
# ...

# %%
# !pip install torchsummary DNN_printer

# %%
# %cd /kaggle/working/OCT2Former
# Out:
# /kaggle/working/OCT2Former

# %%
# !python train.py --dataset='ROSE' --num_epochs=100 --dataset_file_list='utils/ROSE-1.csv' --data_root='/kaggle/input/rose-1/ROSE-1/SVC/train/img' --target_root='/kaggle/input/rose-1/ROSE-1/SVC/train/gt' --run_dir='ROSE-1' --in_channel=1 --batch_size=2 --lr=5e-4 --img_aug
# Out:
# 2024-06-24 20:15:06.874493: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-24 20:15:06.874566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-24 20:15:06.875984: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# k_fold is None
# ###################### Train Start & OCT2Former ######################
# train dataset: 27
# val dataset: 3
# ...
